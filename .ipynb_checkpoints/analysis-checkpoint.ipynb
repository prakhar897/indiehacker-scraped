# %%
import pandas as pd
import numpy as np
import json

# %%
# Assuming you have two JSON files named file1.json and file2.json
with open('data1.json', 'r') as f:
    data1 = json.load(f)

with open('./data2.json', 'r') as f:
    data2 = json.load(f)
    
with open('./data3.json', 'r') as f:
    data3 = json.load(f)

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)
df3 = pd.DataFrame(data3)

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'analysis.ipynb',
#  'data1.json',
#  'data2.json',
#  'data3.json',
#  'snippets.js']

# %%
merged_df = pd.concat([df1, df2, df3], ignore_index=True)
merged_df
# Out:
#                                                    link      revenue  \
# 0          https://www.indiehackers.com/product/nextiva  $10,000,000
# 1           https://www.indiehackers.com/product/envato   $8,000,000
# 2      https://www.indiehackers.com/product/boom-bucket   $5,500,000
# 3      https://www.indiehackers.com/product/signum-ai-2   $4,000,000
# 4      https://www.indiehackers.com/product/grasshopper   $2,500,000
# ...                                                 ...          ...
# 2974      https://www.indiehackers.com/product/unrolled           $0
# 2975       https://www.indiehackers.com/product/unremot           $0
# 2976  https://www.indiehackers.com/product/unreal-im...           $0
# 2977  https://www.indiehackers.com/product/unnamed-c...           $0
# 2978       https://www.indiehackers.com/product/unnamed           $0
#
#      revenue_period      revenue_explanation
# 0             month    self-reported revenue
# 1             month    self-reported revenue
# ...

# %%
merged_df = merged_df.drop_duplicates()
merged_df = merged_df.reset_index(drop=True)
len(merged_df)
# Out:
# 2868

# %%
sorted_df = merged_df.sort_values(by='link')
sorted_df.head(50)
# Out:
#                                                    link         revenue  \
# 1195  https://www.indiehackers.com/product/1000-poun...              $0
# 569       https://www.indiehackers.com/product/1blocker         $18,000
# 981     https://www.indiehackers.com/product/1daydesign          $7,833
# 1829     https://www.indiehackers.com/product/1do-today              $0
# 915   https://www.indiehackers.com/product/1m-10m-in...         $10,000
# 1316  https://www.indiehackers.com/product/1st-thing...  does not exist
# 914      https://www.indiehackers.com/product/1tools-co         $10,000
# 913       https://www.indiehackers.com/product/20xmedia         $10,000
# 431       https://www.indiehackers.com/product/21yunbox         $28,778
# 642   https://www.indiehackers.com/product/24-hours-mvp         $15,000
# 580    https://www.indiehackers.com/product/24k-jewelry         $16,950
# 1910  https://www.indiehackers.com/product/2quiet2ma...             $25
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Count the occurrences of each unique value
counts = merged_df['revenue_explanation'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Revenue Explanation')
plt.show()

# %%
def convert_to_numeric(value):
    try:
        return int(value.replace('$', '').replace(',', ''))
    except (ValueError, AttributeError):
        return None
    
rev_sorted_df = merged_df.sort_values(by='revenue')

rev_sorted_df["revenue_int"] = rev_sorted_df['revenue'].apply(convert_to_numeric)

# %%
print(len(rev_sorted_df[rev_sorted_df["revenue_int"] >= 0]))
print(len(rev_sorted_df[rev_sorted_df["revenue_int"] == 0]))
print(len(rev_sorted_df[rev_sorted_df["revenue_int"] > 0]))
print(len(rev_sorted_df[rev_sorted_df["revenue_int"] > 100]))
print(len(rev_sorted_df[rev_sorted_df["revenue_int"] > 1000]))
print(len(rev_sorted_df[rev_sorted_df["revenue_int"] > 10000]))
# Out:
# 2799
# 1516
# 1283
# 1171
# 1071
# 749

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import csv

# Set up the Chrome driver
driver = webdriver.Chrome()

# %%
url = "https://www.indiehackers.com/product/highsign"

# %%
driver.get(url)
driver.implicitly_wait(10)

# %%
print(response.content)
# Out:
# b'<!DOCTYPE html><html lang=en-US><head><script src=https://cdn.cookielaw.org/consent/f297b688-9e8b-4c3c-bee2-338878d82ce5/OtAutoBlock.js></script><script src=https://cdn.cookielaw.org/scripttemplates/otSDKStub.js charset=UTF-8 data-domain-script=f297b688-9e8b-4c3c-bee2-338878d82ce5></script><script>function OptanonWrapper(){}</script><meta charset=utf-8><meta content="IE=edge" http-equiv=X-UA-Compatible><meta content=unsafe-url name=referrer><link href=/images/favicons/favicon--16x16.png rel=icon sizes=16x16 type=image/png><link href=/images/favicons/favicon--32x32.png rel=icon sizes=32x32 type=image/png><link href=/images/favicons/favicon--192x192.png rel=icon sizes=192x192 type=image/png><link href=/images/logos/apple-touch-icon.png rel=apple-touch-icon-precomposed><meta content=#1f364d name=theme-color><meta content=%7B%22environment%22%3A%22production%22%2C%22historySupportMiddleware%22%3Atrue%2C%22locationType%22%3A%22auto%22%2C%22modulePrefix%22%3A%22indie-hackers%22%2C%22root
# ...
